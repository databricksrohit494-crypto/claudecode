# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv
load_dotenv()

import os

if os.getenv("ANTHROPIC_API_KEY") is None:
    raise ValueError("ANTHROPIC_API_KEY environment variable not set")
else:
    print("ANTHROPIC_API_KEY environment variable is set")
# Out:
# e:\vscode\claudecode\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# ANTHROPIC_API_KEY environment variable is set

# %%
llm = ChatAnthropic(model="claude-haiku-4-5-20251001")

response = llm.invoke("give me a code to create  pandas dataframe with 3 columns and 5 rows")
response.content
# Out:
# "# Create a pandas DataFrame with 3 columns and 5 rows\n\n```python\nimport pandas as pd\n\n# Method 1: Using a dictionary\ndf = pd.DataFrame({\n    'Column1': [1, 2, 3, 4, 5],\n    'Column2': ['A', 'B', 'C', 'D', 'E'],\n    'Column3': [10.5, 20.3, 15.7, 25.1, 30.2]\n})\n\nprint(df)\n```\n\n**Output:**\n```\n   Column1 Column2  Column3\n0        1       A     10.5\n1        2       B     20.3\n2        3       C     15.7\n3        4       D     25.1\n4        5       E     30.2\n```\n\n---\n\n### Alternative Methods:\n\n**Method 2: Using a list of lists**\n```python\ndf = pd.DataFrame([\n    [1, 'A', 10.5],\n    [2, 'B', 20.3],\n    [3, 'C', 15.7],\n    [4, 'D', 25.1],\n    [5, 'E', 30.2]\n], columns=['Column1', 'Column2', 'Column3'])\n```\n\n**Method 3: Using random data**\n```python\nimport numpy as np\n\ndf = pd.DataFrame(\n    np.random.randn(5, 3),\n    columns=['Column1', 'Column2', 'Column3']\n)\n```\n\nChoose the method that best fits your needs! 🎯"
